# %% [markdown]
# <a href="https://colab.research.google.com/github/Nelux1/PYTHON-PLUS/blob/master/Marcos_Suarez.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Nombre:** Marcos Suarez
# # Parte 1
# ## Enunciado asignado
# **Enunciado 4:** dado el archivo de registros de jugadas (eventos) de MemPy, mostrar un gráfico con los 3 (tres) usuarios que más tiempo jugaron el juego (independientemente del resultado de la partida.

# %%
import os
import pandas as pd
from matplotlib import pyplot as plt

archivo=os.path.join(os.getcwd(),'sample_data/datos_estadisticos.csv')
archivo_csv=open(archivo,"r")

data_set= pd.read_csv(archivo_csv,encoding='utf-8')

por_tiempo = data_set.sort_values('Tiempo',ascending=False)

usuario_tiempo=por_tiempo[['Usuarie - nick','Tiempo']].head(n=3)
print(usuario_tiempo)
usuario_tiempo.plot(kind='bar')
# Out:
#   Usuarie - nick      Tiempo
# 1           pepe  258.223502
# 2          CHARO  251.507447
# 3          NEGRO  119.516119

# %% [markdown]
# # Parte 2
#
# ## Creterio elegido
#
# Dataset: marvel-wikia-data.csv
#
# Criterio: Top 50 superheroes de marvel por año

# %%
import wordcloud

archivo2=os.path.join(os.getcwd(),'sample_data/marvel-wikia-data.csv')
archivo_csv2=open(archivo2,"r")
 
data_set2= pd.read_csv(archivo_csv2, encoding='utf-8')
 
ordenado_por_año=data_set2.sort_values('Year',ascending=False)
 
top50= ordenado_por_año['name'].head(n=50)
 
top50
 
from wordcloud import WordCloud, STOPWORDS


def plot_cloud(wordcloud):   
   plt.figure(figsize= (10,8))
   plt.imshow(wordcloud)
   plt.axis("off")
 
text= str(top50)
#el siguiente tecxto esta mencionado ya que con el reemplazo no quedaba linda la imagen 
#text=str([c.replace(' ','_')for c in top50])
wordcloud= WordCloud(width=200, height=300,random_state=1,background_color='black',colormap='Set2',collocations=False,stopwords=STOPWORDS).generate(text)
 
plot_cloud(wordcloud)
